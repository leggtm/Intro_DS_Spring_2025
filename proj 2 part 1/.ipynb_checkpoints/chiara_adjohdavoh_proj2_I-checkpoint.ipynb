# %% [markdown]
# # Project 2 - Part I
#
# ## Environmental Trends 2000-2024
#
# ### Chiara Adjoh-Davoh
#
# ### Student ID: 004002088

# %% [markdown]
# ## Introduction
#
# Climate change affects us all. Whether you believe it or not, the signs are there that the planet's climate is changing in ways that are harmful to not only our lives, but  the lives of every living thing. There's not just one data point that can be used to see climate change in action, but rather many data points and trends that point to the world's climate heading in a bad direction. This data set uses data across a number of climate related measurments including average temps, CO2 emissions, rainfall, etc. to show the environmental trends.

# %%
# 1

import pandas as pd #imports the pandas library

df = pd.read_csv("temperature.csv") #imports the csv file with the enviromental data

display(df.head()) #prints first 5 rows 
print("\n") #creates a line break for visual clarity
display(df.tail()) #prints the last 5 rows
# Out:
#    Year    Country  Avg_Temperature_degC  CO2_Emissions_tons_per_capita  \
# 0  2006         UK                   8.9                            9.3
# 1  2019        USA                  31.0                            4.8
# 2  2014     France                  33.9                            2.8
# 3  2010  Argentina                   5.9                            1.8
# 4  2007    Germany                  26.9                            5.6
#
#    Sea_Level_Rise_mm  Rainfall_mm  Population  Renewable_Energy_pct  \
# 0                3.1         1441   530911230                  20.4
# 1                4.2         2407   107364344                  49.2
# 2                2.2         1241   441101758                  33.3
# 3                3.2         1892  1069669579                  23.7
# 4                2.4         1743   124079175                  12.5
#
#    Extreme_Weather_Events  Forest_Area_pct
# 0                      14             59.8
# ...

# %% [markdown]
# ## #1
#
# The dataset has 1000 rows of data and 10 columns. The dataframe includes first, the year the data was collected, then the country it was collected from, then a number of climate related statistics and measurments for the corresponding year/country. The code imports the pandas library to use in the future, then imports the data as a dataframe, and then prints the first few and last few rows. We can tell the shape of the data using .shape to determine there are 1000 rows and 10 columns.

# %% [markdown]
# ## #2
#
# Year is a datetime variable. Country is a categorical variable. The remaining 8 variables are numerical. They representing real counting number values.

# %%
# 3

display(df.isnull()) #displays the null status of all rows
display(df.info()) #displays important information about how many non null rows there are
# Out:
#       Year  Country  Avg_Temperature_degC  CO2_Emissions_tons_per_capita  \
# 0    False    False                 False                          False
# 1    False    False                 False                          False
# 2    False    False                 False                          False
# 3    False    False                 False                          False
# 4    False    False                 False                          False
# ..     ...      ...                   ...                            ...
# 995  False    False                 False                          False
# 996  False    False                 False                          False
# 997  False    False                 False                          False
# 998  False    False                 False                          False
# 999  False    False                 False                          False
#
#      Sea_Level_Rise_mm  Rainfall_mm  Population  Renewable_Energy_pct  \
# ...

# %% [markdown]
# ## #3
#
# There are no missing values in the dataset. If there were missing values, an easy way to deal with them would be to remove rows that contain missing values as to not complicated the dataset. There are plenty of rows, so the removal of a few would not have a large effect on the numbers. We can do this using df.dropna(). The current code displays the null status of all rows and columns and then displays how many non-null values we have per column.

# %%
# 4

df = df.drop_duplicates() #drops duplicate values

display(df.info()) #displays info about the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Year                           1000 non-null   int64
#  1   Country                        1000 non-null   object
#  2   Avg_Temperature_degC           1000 non-null   float64
#  3   CO2_Emissions_tons_per_capita  1000 non-null   float64
#  4   Sea_Level_Rise_mm              1000 non-null   float64
#  5   Rainfall_mm                    1000 non-null   int64
#  6   Population                     1000 non-null   int64
#  7   Renewable_Energy_pct           1000 non-null   float64
#  8   Extreme_Weather_Events         1000 non-null   int64
#  9   Forest_Area_pct                1000 non-null   float64
# dtypes: float64(5), int64(4), object(1)
# memory usage: 78.3+ KB
# None

# %% [markdown]
# ## #4
#
# The code drops rows that are duplicates of other rows and then displays the data info to see how many were dropped. Since the size is still 1000 x 10, it seems there were no duplicate rows dropped.

# %%
# 5

df_threshold = df.loc[df["Rainfall_mm"] < 1000, ["Year", "Country", "Rainfall_mm"]] #filters for only countries and years that had less then 1000 mm of rainfall
df_pop = df["Population"] #displays just the population categories of each entry
df_France = df[df["Country"] == "France"] #displays only the rows where the country is France

display(df_threshold)
display(df_pop)
display(df_France)
# Out:
#      Year         Country  Rainfall_mm
# 7    2018  'South Africa'          827
# 11   2023  'South Africa'          875
# 12   2020          Brazil          762
# 13   2003             USA          766
# 20   2023          France          545
# ..    ...             ...          ...
# 975  2003  'South Africa'          863
# 989  2011              UK          713
# 991  2005       Indonesia          518
# 994  2018       Australia          829
# 997  2019       Argentina          891
#
# [202 rows x 3 columns]
# 0       530911230
# 1       107364344
# 2       441101758
# 3      1069669579
# 4       124079175
#           ...
# 995    1358019778
# 996     876123161
# 997    1120533308
# 998     380662109
# 999     398407112
# Name: Population, Length: 1000, dtype: int64
#      Year Country  Avg_Temperature_degC  CO2_Emissions_tons_per_capita  \
# 2    2014  France                  33.9                            2.8
# ...

# %% [markdown]
# ## #5
#
# The code filters the dataframe in two ways: threshold and by category. The first line uses the loc function to filter the dataframe only for entries where rainfall was less than 1000 mm in that year. That could be very helpful for identifying countries in a drought. The second line filters for only the population of each row. The last line filters for the rows where the country the data is taken from is France. This could be useful for when you would only like to see the climate variables present in certain countries.

# %%
# 6

display(df.describe()) #prints a statistical description of the numerical columns
# Out:
#               Year  Avg_Temperature_degC  CO2_Emissions_tons_per_capita  \
# count  1000.000000           1000.000000                    1000.000000
# mean   2011.432000             19.883100                      10.425800
# std       7.147199              8.542897                       5.614665
# min    2000.000000              5.000000                       0.500000
# 25%    2005.000000             12.175000                       5.575000
# 50%    2012.000000             20.100000                      10.700000
# 75%    2018.000000             27.225000                      15.400000
# max    2023.000000             34.900000                      20.000000
#
#        Sea_Level_Rise_mm  Rainfall_mm    Population  Renewable_Energy_pct  \
# count        1000.000000  1000.000000  1.000000e+03           1000.000000
# mean            3.009600  1738.761000  7.053830e+08             27.300500
# std             1.146081   708.976616  4.093910e+08             12.970808
# ...

# %% [markdown]
# ## #6
#
# The code prints a statistical description of the numerical columns, displayign things such as count, mean, standard deviation and more. Something I found interesting about the data shown is the standard deviation of the CO2 emissions per capita. The STD is about half of the mean, which is quite high. This means that there is a lot of variance on the amount of CO2 released. This makes sense to me, as wealthy countries produce much more CO2 per capita than less wealthy countries.

# %%
# 7

display(df["Country"].value_counts()) #displays the count for each value present in the Countries column
display(df["Year"].value_counts()) #displays the count for each value present in the Years column
# Out:
# Country
# Indonesia         75
# Russia            74
# USA               73
# 'South Africa'    73
# India             70
# Argentina         67
# China             67
# Brazil            67
# Canada            67
# France            66
# UK                65
# Japan             63
# Germany           61
# Australia         57
# Mexico            55
# Name: count, dtype: int64
# Year
# 2000    53
# 2016    51
# 2002    51
# 2004    50
# 2018    46
# 2021    46
# 2022    45
# 2011    44
# 2014    44
# 2015    43
# 2020    43
# 2012    42
# 2023    42
# 2001    41
# 2003    41
# 2019    40
# 2007    40
# 2006    39
# 2005    37
# 2008    36
# 2009    33
# 2017    32
# 2013    31
# 2010    30
# Name: count, dtype: int64

# %% [markdown]
# ## #7
#
# First, I analyzed the data counts for the countries. Indonesia has the most amount of entries, and Mexico has the least. I wonder if this is a bit random or it has something to do with the types of governments that the countries have. Then, I used year as a categorical variable. I think, in this case, this is okay because the year is not being used as a measurement or a counting variable. It's simply a way to help categorize the data. I found that 2000 had the most entries and 2010 had the least. It seems that there's an even dispersement of recent and older data.

# %%
# 8

display(df.groupby("Country")['CO2_Emissions_tons_per_capita'].mean()) #diplays the mean CO2 emissions of each country
display(df.groupby("Year")['CO2_Emissions_tons_per_capita'].mean()) #displays the worldwide mean of all the CO2 emissions grouped by year
display(df.groupby("Country").median()) #displays median of all columns grouped by country
# Out:
# Country
# 'South Africa'     9.617808
# Argentina         10.447761
# Australia          8.900000
# Brazil            10.838806
# Canada            10.113433
# China             10.835821
# France            10.966667
# Germany            9.880328
# India             10.694286
# Indonesia         11.021333
# Japan             10.960317
# Mexico             9.347273
# Russia             8.967568
# UK                12.650769
# USA               10.882192
# Name: CO2_Emissions_tons_per_capita, dtype: float64
# Year
# 2000    11.224528
# 2001     9.929268
# 2002     9.933333
# 2003    11.085366
# 2004    10.000000
# 2005     8.537838
# 2006    10.497436
# 2007    10.335000
# 2008    10.375000
# 2009    10.363636
# 2010     9.873333
# 2011     9.809091
# 2012    10.640476
# 2013    11.135484
# 2014    11.409091
# 2015     9.667442
# 2016    10.398039
# 2017     8.234375
# 2018    10.443478
# 2019     9.812500
# 2020    10.246512
# 2021    11.521739
# 2022    12.326667
# ...

# %% [markdown]
# ## #8
#
# I first wanted to try looking at a specific category and choose CO2 emissions grouped by country. I think this yields very specific results that could be quite useful if trying to find a specific country or group of countries that is contributing the most to climate change. Then I tried looking at the mean CO2 emissions, now grouped by year instead of country. I think this could also be very useful if trying to see how emissions change worldwide year after year. Lastly, I looked at the median of all of the columns, grouped by country.

# %% [markdown]
# ## #9 & #10
#
# Over the course of my analysis, I came to a few conclusions. Firstly, I think this data has a bit of inherent bias to it. Not every country is going to report their data every single year, or couple of months, whether that be due to their lack of infrastructure to do so or their unwillingness to. At the end of the day, we can only rely on the data that the countries choose to self report. Additionally, there is a lot to be said of the data that isn't included. Only a small number of countries are represented in this data. What did their climate reports look like and what affect might that have had on the overall numbers? There's an overrrepresentation of Western countries in this data set that can create a slant on the worldwide statistics. Another problem with this dataset is that there is a bit of confusion on the chronological nature of the data. Only 15 countries are reporting, however most years had well over 50 entries, meaning each country submited more than three times a year. In what order does this data come? This could be a big deal. Having the month associated with it could be a big help. Something of note is the overall increase in many of these key statistics over the years. It doesn't surprise me at all that as we continue to consume and destroy our planet, these numbers seem to be on the rise. I find it interesting however that the countries with the lowest CO2 emissions per capita seemed to have the higher average temperatures, at least in this dataset. In Part II, when using visualization, I would like to see some boxplots to really compare the medians and quarters of these datasets, to see if there are outliers to watch out for. The questions I would ask are what can these boxplots tells about the statistical outliers in this data and how can the scatterplots show us the correlation between certain variables?

# %% [markdown]
# Dataset Reference: https://www.kaggle.com/datasets/adilshamim8/temperature?resource=download
